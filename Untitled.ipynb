# %%
import sys
sys.path.insert(0, r'C:\Users\Bo\projects\neuromorphic-sandbox')

from src.simulation import BasicNeuromorphicSim
from src.topology import TopologyGenerator
import matplotlib.pyplot as plt

print("✓ Imports successful!")

# Create a simple simulation
sim = BasicNeuromorphicSim(n_neurons=1000)
sim.create_network()
results = sim.run(duration=0.5)

print(f"✓ Simulation complete!")
print(f"  Firing rate: {results['firing_rate']:.2f} Hz")
print(f"  Total spikes: {results['num_spikes']}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys
#       2 sys.path.insert(0, r'C:\Users\Bo\projects\neuromorphic-sandbox')
#       3
# ----> 4 from src.simulation import BasicNeuromorphicSim
#       5 from src.topology import TopologyGenerator
#       6 import matplotlib.pyplot as plt
#       7
#
# File ~\projects\neuromorphic-sandbox\src\simulation.py:1
# ----> 1 import brian2 as b2
#       2 import numpy as np
#       3 from typing import Dict
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\__init__.py:91
#      87     del rate
#      89 __docformat__ = "restructuredtext en"
# ---> 91 from brian2.only import *
#      92 from brian2.only import test
#      95 # Check for outdated dependency versions
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\only.py:28
#      26 from brian2.core.functions import *
#      27 from brian2.core.preferences import *
# ---> 28 from brian2.core.clocks import *
#      29 from brian2.equations import *
#      31 # The base class only depends on the above sets
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\core\clocks.py:11
#       9 from brian2.core.names import Nameable
#      10 from brian2.core.variables import Variables
# ---> 11 from brian2.groups.group import VariableOwner
#      12 from brian2.units.allunits import second
#      13 from brian2.units.fundamentalunits import Quantity, check_units
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\groups\__init__.py:5
#       1 """
#       2 Package providing groups such as `NeuronGroup` or `PoissonGroup`.
#       3 """
# ----> 5 from .group import *
#       6 from .neurongroup import *
#       7 from .subgroup import *
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\groups\group.py:17
#      13 from collections.abc import Mapping
#      15 import numpy as np
# ---> 17 from brian2.codegen.codeobject import create_runner_codeobj
#      18 from brian2.core.base import BrianObject, weakproxy_with_fallback
#      19 from brian2.core.functions import Function
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\codegen\__init__.py:9
#       1 """
#       2 Package providing the code generation framework.
#       3 """
#       5 # Import the runtime packages so that they can register their preferences
#       6
#       7 # isort:skip_file
# ----> 9 from .runtime import *
#      10 from . import _prefs
#      11 from . import cpp_prefs as _cpp_prefs
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\codegen\runtime\__init__.py:18
#      11 prefs.register_preferences(
#      12     "codegen.runtime",
#      13     "Runtime codegen preferences (see subcategories for individual targets)",
#      14 )
#      16 logger = get_logger(__name__)
# ---> 18 from .numpy_rt import *
#      20 try:
#      21     from .cython_rt import *
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\codegen\runtime\numpy_rt\__init__.py:9
#       1 """
#       2 Numpy runtime implementation.
#       3
#    (...)      6 .. document_brian_prefs:: codegen.runtime.numpy
#       7 """
# ----> 9 from .numpy_rt import *
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\codegen\runtime\numpy_rt\numpy_rt.py:21
#      13 from brian2.core.variables import (
#      14     ArrayVariable,
#      15     AuxiliaryVariable,
#      16     DynamicArrayVariable,
#      17     Subexpression,
#      18 )
#      20 from ...codeobject import CodeObject, check_compiler_kwds, constant_or_scalar
# ---> 21 from ...generators.numpy_generator import NumpyCodeGenerator
#      22 from ...targets import codegen_targets
#      23 from ...templates import Templater
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\codegen\generators\__init__.py:12
#       6 prefs.register_preferences(
#       7     "codegen.generators",
#       8     "Codegen generator preferences (see subcategories for individual languages)",
#       9 )
#      11 from .base import *
# ---> 12 from .cpp_generator import *
#      13 from .numpy_generator import *
#      15 try:
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\codegen\generators\cpp_generator.py:5
#       1 import itertools
#       3 import numpy
# ----> 5 from brian2.codegen.cpp_prefs import C99Check
#       6 from brian2.core.functions import DEFAULT_FUNCTIONS, Function
#       7 from brian2.core.preferences import BrianPreference, prefs
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\codegen\cpp_prefs.py:10
#       1 """
#       2 Preferences related to C++ compilation
#       3
#    (...)      7
#       8 """
# ---> 10 import distutils
#      11 import json
#      12 import os
#
# ModuleNotFoundError: No module named 'distutils'

# %%
import sys
sys.path.insert(0, r'C:\Users\Bo\projects\neuromorphic-sandbox')

from src.simulation import BasicNeuromorphicSim
from src.topology import TopologyGenerator
import matplotlib.pyplot as plt

print("✓ Imports successful!")

# Create a simple simulation
sim = BasicNeuromorphicSim(n_neurons=1000)
sim.create_network()
results = sim.run(duration=0.5)

print(f"✓ Simulation complete!")
print(f"  Firing rate: {results['firing_rate']:.2f} Hz")
print(f"  Total spikes: {results['num_spikes']}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       1 import sys
#       2 sys.path.insert(0, r'C:\Users\Bo\projects\neuromorphic-sandbox')
#       3
# ----> 4 from src.simulation import BasicNeuromorphicSim
#       5 from src.topology import TopologyGenerator
#       6 import matplotlib.pyplot as plt
#       7
#
# File ~\projects\neuromorphic-sandbox\src\simulation.py:1
# ----> 1 import brian2 as b2
#       2 import numpy as np
#       3 from typing import Dict
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\__init__.py:57
#      53     from numpy.random import *
#      55 # Make sure that Brian's unit-aware functions are used, even when directly
#      56 # using names prefixed with numpy or np
# ---> 57 import brian2.numpy_ as numpy
#      58 import brian2.numpy_ as np
#      60 try:
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\numpy_.py:12
#       8 # isort:skip_file
#       9 # flake8: noqa
#      11 from numpy import *
# ---> 12 from brian2.units.unitsafefunctions import *
#      14 # These will not be imported with a wildcard import to not overwrite the
#      15 # builtin names (mimicking the numpy behaviour)
#      16 from builtins import bool, float, complex
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\units\__init__.py:7
#       1 """
#       2 The unit system.
#       3 """
#       5 # isort:skip_file
# ----> 7 from .allunits import (
#       8     # basic units
#       9     pamp,
#      10     namp,
#      11     uamp,
#      12     mamp,
#      13     amp,
#      14     kamp,
#      15     Mamp,
#      16     Gamp,
#      17     Tamp,
#      18     kelvin,
#      19     kilogram,  # silly to have mkilogram, etc...
#      20     pmetre,
#      21     nmetre,
#      22     umetre,
#      23     mmetre,
#      24     metre,
#      25     kmetre,
#      26     Mmetre,
#      27     Gmetre,
#      28     Tmetre,
#      29     pmeter,
#      30     nmeter,
#      31     umeter,
#      32     mmeter,
#      33     meter,
#      34     kmeter,
#      35     Mmeter,
#      36     Gmeter,
#      37     Tmeter,
#      38     cmetre,
#      39     cmeter,  # quite commonly used
#      40     psecond,
#      41     nsecond,
#      42     usecond,
#      43     msecond,
#      44     second,
#      45     ksecond,
#      46     Msecond,
#      47     Gsecond,
#      48     Tsecond,
#      49     pmole,
#      50     nmole,
#      51     umole,
#      52     mmole,
#      53     mole,
#      54     kmole,
#      55     Mmole,
#      56     Gmole,
#      57     Tmole,
#      58     # derived units
#      59     pcoulomb,
#      60     ncoulomb,
#      61     ucoulomb,
#      62     mcoulomb,
#      63     coulomb,
#      64     kcoulomb,
#      65     Mcoulomb,
#      66     Gcoulomb,
#      67     Tcoulomb,
#      68     pfarad,
#      69     nfarad,
#      70     ufarad,
#      71     mfarad,
#      72     farad,
#      73     kfarad,
#      74     Mfarad,
#      75     Gfarad,
#      76     Tfarad,
#      77     pgram,
#      78     ngram,
#      79     ugram,
#      80     mgram,
#      81     gram,
#      82     kgram,
#      83     Mgram,
#      84     Ggram,
#      85     Tgram,
#      86     pgramme,
#      87     ngramme,
#      88     ugramme,
#      89     mgramme,
#      90     gramme,
#      91     kgramme,
#      92     Mgramme,
#      93     Ggramme,
#      94     Tgramme,
#      95     phertz,
#      96     nhertz,
#      97     uhertz,
#      98     mhertz,
#      99     hertz,
#     100     khertz,
#     101     Mhertz,
#     102     Ghertz,
#     103     Thertz,
#     104     pjoule,
#     105     njoule,
#     106     ujoule,
#     107     mjoule,
#     108     joule,
#     109     kjoule,
#     110     Mjoule,
#     111     Gjoule,
#     112     Tjoule,
#     113     pmolar,
#     114     nmolar,
#     115     umolar,
#     116     mmolar,
#     117     molar,
#     118     kmolar,
#     119     Mmolar,
#     120     Gmolar,
#     121     Tmolar,
#     122     pliter,
#     123     nliter,
#     124     uliter,
#     125     mliter,
#     126     liter,
#     127     kliter,
#     128     Mliter,
#     129     Gliter,
#     130     Tliter,
#     131     plitre,
#     132     nlitre,
#     133     ulitre,
#     134     mlitre,
#     135     litre,
#     136     klitre,
#     137     Mlitre,
#     138     Glitre,
#     139     Tlitre,
#     140     ppascal,
#     141     npascal,
#     142     upascal,
#     143     mpascal,
#     144     pascal,
#     145     kpascal,
#     146     Mpascal,
#     147     Gpascal,
#     148     Tpascal,
#     149     pohm,
#     150     nohm,
#     151     uohm,
#     152     mohm,
#     153     ohm,
#     154     kohm,
#     155     Mohm,
#     156     Gohm,
#     157     Tohm,
#     158     psiemens,
#     159     nsiemens,
#     160     usiemens,
#     161     msiemens,
#     162     siemens,
#     163     ksiemens,
#     164     Msiemens,
#     165     Gsiemens,
#     166     Tsiemens,
#     167     pvolt,
#     168     nvolt,
#     169     uvolt,
#     170     mvolt,
#     171     volt,
#     172     kvolt,
#     173     Mvolt,
#     174     Gvolt,
#     175     Tvolt,
#     176     pwatt,
#     177     nwatt,
#     178     uwatt,
#     179     mwatt,
#     180     watt,
#     181     kwatt,
#     182     Mwatt,
#     183     Gwatt,
#     184     Twatt,
#     185 )
#     186 from .unitsafefunctions import *
#     187 from .unitsafefunctions import __all__ as unitsafefunctions_all
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\units\allunits.py:14
#      10 # fmt: off
#      11 # flake8: noqa
#      12 import itertools
# ---> 14 from .fundamentalunits import (
#      15     Unit,
#      16     additional_unit_register,
#      17     get_or_create_dimension,
#      18     standard_unit_register,
#      19 )
#      21 __all__ = [
#      22     "metre",
#      23     "meter",
#    (...)   2091     "celsius"  # Dummy object raising an error
#    2092     ]
#    2095 Unit.automatically_register_units = False
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\units\fundamentalunits.py:984
#     952     """
#     953     Create a new `Quantity` with the given dimensions. Calls
#     954     `get_or_create_dimensions` with the dimension tuple of the `dims`
#    (...)    979     get_or_create_dimensions
#     980     """
#     981     return Quantity(floatval, get_or_create_dimension(dims._dims))
# --> 984 class Quantity(np.ndarray):
#     985     """
#     986     A number with an associated physical dimension. In most cases, it is not
#     987     necessary to create a Quantity object by hand, instead use multiplication
#    (...)   1051     in_best_unit
#    1052     """
#    1054     __slots__ = ["dim"]
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\units\fundamentalunits.py:1661, in Quantity()
#    1659 mean = wrap_function_keep_dimensions(np.ndarray.mean)
#    1660 min = wrap_function_keep_dimensions(np.ndarray.min)
# -> 1661 ptp = wrap_function_keep_dimensions(np.ndarray.ptp)
#    1663 # To work around an issue in matplotlib 1.3.1 (see
#    1664 # https://github.com/matplotlib/matplotlib/pull/2591), we make `ravel`
#    1665 # return a unitless array and emit a warning explaining the issue.
#    1666 use_matplotlib_units_fix = False
#
# AttributeError: type object 'numpy.ndarray' has no attribute 'ptp'

# %%
import sys
sys.path.insert(0, r'C:\Users\Bo\projects\neuromorphic-sandbox')

from src.simulation import BasicNeuromorphicSim
from src.topology import TopologyGenerator
import matplotlib.pyplot as plt

print("✓ Imports successful!")

# Create a simple simulation
sim = BasicNeuromorphicSim(n_neurons=1000)
sim.create_network()
results = sim.run(duration=0.5)

print(f"✓ Simulation complete!")
print(f"  Firing rate: {results['firing_rate']:.2f} Hz")
print(f"  Total spikes: {results['num_spikes']}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 import sys
#       2 sys.path.insert(0, r'C:\Users\Bo\projects\neuromorphic-sandbox')
#       3
# ----> 4 from src.simulation import BasicNeuromorphicSim
#       5 from src.topology import TopologyGenerator
#       6 import matplotlib.pyplot as plt
#       7
#
# File ~\projects\neuromorphic-sandbox\src\simulation.py:1
# ----> 1 import brian2 as b2
#       2 import numpy as np
#       3 from typing import Dict
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\__init__.py:57
#      53     from numpy.random import *
#      55 # Make sure that Brian's unit-aware functions are used, even when directly
#      56 # using names prefixed with numpy or np
# ---> 57 import brian2.numpy_ as numpy
#      58 import brian2.numpy_ as np
#      60 try:
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\numpy_.py:12
#       8 # isort:skip_file
#       9 # flake8: noqa
#      11 from numpy import *
# ---> 12 from brian2.units.unitsafefunctions import *
#      14 # These will not be imported with a wildcard import to not overwrite the
#      15 # builtin names (mimicking the numpy behaviour)
#      16 from builtins import bool, float, complex
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\units\__init__.py:7
#       1 """
#       2 The unit system.
#       3 """
#       5 # isort:skip_file
# ----> 7 from .allunits import (
#       8     # basic units
#       9     pamp,
#      10     namp,
#      11     uamp,
#      12     mamp,
#      13     amp,
#      14     kamp,
#      15     Mamp,
#      16     Gamp,
#      17     Tamp,
#      18     kelvin,
#      19     kilogram,  # silly to have mkilogram, etc...
#      20     pmetre,
#      21     nmetre,
#      22     umetre,
#      23     mmetre,
#      24     metre,
#      25     kmetre,
#      26     Mmetre,
#      27     Gmetre,
#      28     Tmetre,
#      29     pmeter,
#      30     nmeter,
#      31     umeter,
#      32     mmeter,
#      33     meter,
#      34     kmeter,
#      35     Mmeter,
#      36     Gmeter,
#      37     Tmeter,
#      38     cmetre,
#      39     cmeter,  # quite commonly used
#      40     psecond,
#      41     nsecond,
#      42     usecond,
#      43     msecond,
#      44     second,
#      45     ksecond,
#      46     Msecond,
#      47     Gsecond,
#      48     Tsecond,
#      49     pmole,
#      50     nmole,
#      51     umole,
#      52     mmole,
#      53     mole,
#      54     kmole,
#      55     Mmole,
#      56     Gmole,
#      57     Tmole,
#      58     # derived units
#      59     pcoulomb,
#      60     ncoulomb,
#      61     ucoulomb,
#      62     mcoulomb,
#      63     coulomb,
#      64     kcoulomb,
#      65     Mcoulomb,
#      66     Gcoulomb,
#      67     Tcoulomb,
#      68     pfarad,
#      69     nfarad,
#      70     ufarad,
#      71     mfarad,
#      72     farad,
#      73     kfarad,
#      74     Mfarad,
#      75     Gfarad,
#      76     Tfarad,
#      77     pgram,
#      78     ngram,
#      79     ugram,
#      80     mgram,
#      81     gram,
#      82     kgram,
#      83     Mgram,
#      84     Ggram,
#      85     Tgram,
#      86     pgramme,
#      87     ngramme,
#      88     ugramme,
#      89     mgramme,
#      90     gramme,
#      91     kgramme,
#      92     Mgramme,
#      93     Ggramme,
#      94     Tgramme,
#      95     phertz,
#      96     nhertz,
#      97     uhertz,
#      98     mhertz,
#      99     hertz,
#     100     khertz,
#     101     Mhertz,
#     102     Ghertz,
#     103     Thertz,
#     104     pjoule,
#     105     njoule,
#     106     ujoule,
#     107     mjoule,
#     108     joule,
#     109     kjoule,
#     110     Mjoule,
#     111     Gjoule,
#     112     Tjoule,
#     113     pmolar,
#     114     nmolar,
#     115     umolar,
#     116     mmolar,
#     117     molar,
#     118     kmolar,
#     119     Mmolar,
#     120     Gmolar,
#     121     Tmolar,
#     122     pliter,
#     123     nliter,
#     124     uliter,
#     125     mliter,
#     126     liter,
#     127     kliter,
#     128     Mliter,
#     129     Gliter,
#     130     Tliter,
#     131     plitre,
#     132     nlitre,
#     133     ulitre,
#     134     mlitre,
#     135     litre,
#     136     klitre,
#     137     Mlitre,
#     138     Glitre,
#     139     Tlitre,
#     140     ppascal,
#     141     npascal,
#     142     upascal,
#     143     mpascal,
#     144     pascal,
#     145     kpascal,
#     146     Mpascal,
#     147     Gpascal,
#     148     Tpascal,
#     149     pohm,
#     150     nohm,
#     151     uohm,
#     152     mohm,
#     153     ohm,
#     154     kohm,
#     155     Mohm,
#     156     Gohm,
#     157     Tohm,
#     158     psiemens,
#     159     nsiemens,
#     160     usiemens,
#     161     msiemens,
#     162     siemens,
#     163     ksiemens,
#     164     Msiemens,
#     165     Gsiemens,
#     166     Tsiemens,
#     167     pvolt,
#     168     nvolt,
#     169     uvolt,
#     170     mvolt,
#     171     volt,
#     172     kvolt,
#     173     Mvolt,
#     174     Gvolt,
#     175     Tvolt,
#     176     pwatt,
#     177     nwatt,
#     178     uwatt,
#     179     mwatt,
#     180     watt,
#     181     kwatt,
#     182     Mwatt,
#     183     Gwatt,
#     184     Twatt,
#     185 )
#     186 from .unitsafefunctions import *
#     187 from .unitsafefunctions import __all__ as unitsafefunctions_all
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\units\allunits.py:14
#      10 # fmt: off
#      11 # flake8: noqa
#      12 import itertools
# ---> 14 from .fundamentalunits import (
#      15     Unit,
#      16     additional_unit_register,
#      17     get_or_create_dimension,
#      18     standard_unit_register,
#      19 )
#      21 __all__ = [
#      22     "metre",
#      23     "meter",
#    (...)   2091     "celsius"  # Dummy object raising an error
#    2092     ]
#    2095 Unit.automatically_register_units = False
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\units\fundamentalunits.py:984
#     952     """
#     953     Create a new `Quantity` with the given dimensions. Calls
#     954     `get_or_create_dimensions` with the dimension tuple of the `dims`
#    (...)    979     get_or_create_dimensions
#     980     """
#     981     return Quantity(floatval, get_or_create_dimension(dims._dims))
# --> 984 class Quantity(np.ndarray):
#     985     """
#     986     A number with an associated physical dimension. In most cases, it is not
#     987     necessary to create a Quantity object by hand, instead use multiplication
#    (...)   1051     in_best_unit
#    1052     """
#    1054     __slots__ = ["dim"]
#
# File ~\projects\neuromorphic-sandbox\venv\Lib\site-packages\brian2\units\fundamentalunits.py:1661, in Quantity()
#    1659 mean = wrap_function_keep_dimensions(np.ndarray.mean)
#    1660 min = wrap_function_keep_dimensions(np.ndarray.min)
# -> 1661 ptp = wrap_function_keep_dimensions(np.ndarray.ptp)
#    1663 # To work around an issue in matplotlib 1.3.1 (see
#    1664 # https://github.com/matplotlib/matplotlib/pull/2591), we make `ravel`
#    1665 # return a unitless array and emit a warning explaining the issue.
#    1666 use_matplotlib_units_fix = False
#
# AttributeError: type object 'numpy.ndarray' has no attribute 'ptp'
